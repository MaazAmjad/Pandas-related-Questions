# %%
import pandas as pd

# %%
df=pd.read_csv('file.csv')

# %%
df
# Out:
#         Property Address    Property City Property State  Property Zip  \
# 0        1 W Baseline Rd          Phoenix             AZ         85041
# 1        1001 N 19Th Ave          Phoenix             AZ         85009
# 2        10010 N 34Th Pl          Phoenix             AZ         85028
# 3        10019 N 57Th St  Paradise Valley             AZ         85253
# 4        1002 N 27Th Ave          Phoenix             AZ         85009
# ...                  ...              ...            ...           ...
# 1980      9612 S 9Th Ave          Phoenix             AZ         85041
# 1981      9618 S 9Th Ave          Phoenix             AZ         85041
# 1982      9810 N 57Th St  Paradise Valley             AZ         85253
# 1983  9811 E Bell Rd 115       Scottsdale             AZ         85260
# 1984     9851 N 28Th Way          Phoenix             AZ         85028
#
#                   Owner (First Name)   Last Name Middle Name  \
# ...

# %%
df.to_csv('file_name.csv', index=False)
